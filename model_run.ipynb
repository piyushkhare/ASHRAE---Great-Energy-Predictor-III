# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp -r '/content/drive/My Drive/Kaggle_R/train_data.csv' '/content'

# %%
cp -r '/content/drive/My Drive/Kaggle_R/label_.csv' '/content'

# %%
cp -r '/content/drive/My Drive/Kaggle_R/test_data.csv' '/content'

# %%
import pandas as pd
import os
import numpy as np
import gc

# %%
X = pd.read_csv('/content/train_data.csv')

# %%
X = X.loc[:200,]

# %%
X = X.drop(['meter'],axis =1)

# %%
t = X['air_temperature']

# %%
y = pd.read_csv('/content/label_.csv')

# %%
y
# Out:
#      meter_reading
# 0        15.604556
# 1        12.603681
# 2        15.364478
# 3         6.830285
# 4         0.109795
# ..             ...
# 196     114.303138
# 197     296.259000
# 198     190.496000
# 199       4.223571
# 200      11.113200
#
# [201 rows x 1 columns]

# %%
y = y.loc[:200,]

# %%
y
# Out:
#      meter_reading
# 0        15.604556
# 1        12.603681
# 2        15.364478
# 3         6.830285
# 4         0.109795
# ..             ...
# 196     114.303138
# 197     296.259000
# 198     190.496000
# 199       4.223571
# 200      11.113200
#
# [201 rows x 1 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform')

# %%
z = neigh.predict(X)

# %%
x = np.mean(z == y)

# %%
x
# Out:
# meter_reading    0.0
# dtype: float64

# %%
test = pd.read_csv('/content/test_data.csv')

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(training_scores_encoded,clf.predict(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ed3871b6a390> in <module>()
#       1 from sklearn.metrics import mean_squared_log_error
# ----> 2 mean_squared_log_error(training_scores_encoded,clf.predict(X))
#
# NameError: name 'training_scores_encoded' is not defined

# %%
# !pip install setuptools wheel numpy scipy scikit-learn -U

# %%
import lightgbm

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmsle',
    'max_depth': 6, 
    'learning_rate': 0.1,
    'verbose': 0, 
    'early_stopping_round': 20}

# %%
train_data = lightgbm.Dataset(X, label=y)
#test_data = lightgbm.Dataset(x_test, label=y_test)

# %%
model = lightgbm.LGBMRegressor(boosting_type='gbdt',n_estimators=300)

# %%
model.fit(X,y)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model.predict(X)
# Out:
# array([ 23.5761257 , 518.44465875,  23.5761257 , ..., -10.42998372,
#        -10.42998372,   5.70866334])

# %%
y
# Out:
#           meter_reading
# 0             15.604556
# 1             12.603681
# 2             15.364478
# 3              6.830285
# 4              0.109795
# ...                 ...
# 18342119      19.036845
# 18342120       2.564625
# 18342121       1.414208
# 18342122      46.771433
# 18342123       0.835335
#
# [18342124 rows x 1 columns]

# %%
gbm = lgb.LGBMRegressor(num_leaves=31,
                        learning_rate=0.05,
                        n_estimators=10)

# %%
gbm.fit(X,y)

# %%
pred = gbm.predict(X)

# %%
pred

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(y,pred)

# %%
df = pd.read_csv('/content/drive/My Drive/Kaggle_R/sample_submission.csv')

# %%
predict =  gbm.predict(test,num_iteration=gbm.best_iteration_)
df['meter_reading'] = predict
df.to_csv('output')

# %%
df =pd.read_csv('/content/output')

# %%
df1 = df.drop('Unnamed: 0',axis=1)

# %%
df2 = df1.drop(['row_id'],axis=1)

# %%
df1
# Out:
#             row_id  meter_reading
# 0                0    1489.855308
# 1                1    1489.855308
# 2                2    1489.855308
# 3                3    1489.855308
# 4                4    1489.855308
# ...            ...            ...
# 41697595  41697595    1489.855308
# 41697596  41697596    1489.855308
# 41697597  41697597    1489.855308
# 41697598  41697598    1489.855308
# 41697599  41697599    1489.855308
#
# [41697600 rows x 2 columns]

# %%
df2
# Out:
#           meter_reading
# 0           1489.855308
# 1           1489.855308
# 2           1489.855308
# 3           1489.855308
# 4           1489.855308
# ...                 ...
# 41697595    1489.855308
# 41697596    1489.855308
# 41697597    1489.855308
# 41697598    1489.855308
# 41697599    1489.855308
#
# [41697600 rows x 1 columns]

# %%
df1.to_csv('/content/drive/My Drive/submission_3.csv',index=False)

# %%
p1 = pd.read_csv('/content/drive/My Drive/submission_3.csv')

# %%
p1
# Out:
#             row_id  meter_reading
# 0                0    1489.855308
# 1                1    1489.855308
# 2                2    1489.855308
# 3                3    1489.855308
# 4                4    1489.855308
# ...            ...            ...
# 41697595  41697595    1489.855308
# 41697596  41697596    1489.855308
# 41697597  41697597    1489.855308
# 41697598  41697598    1489.855308
# 41697599  41697599    1489.855308
#
# [41697600 rows x 2 columns]

# %%
cp -r '/content/output' '/content/drive/My Drive'

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)

# %%
reg.fit(X,y)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
reg.predict(X)
# Out:
# array([[-3050.78970245],
#        [10081.56020393],
#        [-2207.02235474],
#        ...,
#        [ 3438.63752907],
#        [ 4322.36458838],
#        [ 6490.17894244]])

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X, y)

# %%
t = clf.predict(X)

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(y,clf.predict(X))
# Out:
# 1.5108884005470884

# %%
len(clf.predict(X))
# Out:
# 18342124

# %%
predict = clf.predict(test)
df['meter_reading'] = predict
df.to_csv('/content/drive/My Drive/submission',index=False)

# %%
df3  = pd.read_csv('/content/drive/My Drive/submission')

# %%
df3
# Out:
#             row_id  meter_reading
# 0                0       5.301789
# 1                1      15.604556
# 2                2       0.219591
# 3                3       3.060990
# 4                4      32.836175
# ...            ...            ...
# 41697595  41697595       1.796422
# 41697596  41697596       1.362915
# 41697597  41697597       2.344800
# 41697598  41697598      61.118678
# 41697599  41697599       0.820680
#
# [41697600 rows x 2 columns]

# %%
from sklearn.ensemble import AdaBoostRegressor
regr = AdaBoostRegressor(random_state=0, n_estimators=100)

# %%
regr.fit(X, np.array(y,))

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(y,regr.predict(X))
# Out:
# 5.279772162616282

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
 est = GradientBoostingRegressor(n_estimators=100, learning_rate=0.01, max_depth=1, random_state=0, loss='ls').fit(X,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(y,est.predict(X))

# %%
from sklearn.neural_network import MLPRegressor

# %%
mlp = MLPRegressor(hidden_layer_sizes=(200,100,60,20,10), activation='relu', solver='adam', max_iter=100)

# %%
mlp.fit(X,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:1321: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
